# %%
# 1 - Download, preprocess and split the dataset if necessary. Then create a dataloader for each split

from datasets import load_dataset
import torch
from torch.utils.data import Subset
import random
from Project.utilities.image_dataset import ImageDataset
from utilities.plotter import plot 
from Project.utilities.config import TRAIN_SIZE, VALIDATION_SIZE, TEST_SIZE
from models.network_gan import GAN, Generator, Critic

# Load ImageNet 256x256 from HuggingFace
ds = load_dataset(
    "benjamin-paine/imagenet-1k-256x256"
)

# Apply preprocessing through the custom Dataset class
train_dataset = Subset(
    ImageDataset(ds["train"]),
    range(TRAIN_SIZE),
)

validation_dataset = Subset(
    ImageDataset(ds["validation"]),
    range(VALIDATION_SIZE),
)

test_dataset = Subset(
    ImageDataset(ds["test"]),
    range(TEST_SIZE),
)

gan = GAN(
    Generator(
        latent_dim=128,
        base_channels=512,
        image_shape=(3,256,256)
    ),
    Critic(
        base_channels=32,
        image_shape=(3,256,256)
    )
)

g_history, c_history = gan.train_model(
    n_epochs=150,
    train_dataset=train_dataset,
    batch_size=16,
    lr_G=1e-4,
    lr_C=2e-4,
    r1_weight=1.0,
    r1_every=64,
    ema_decay=0.995,
    preview_every=5,
    resume=True
)
# Out:
# ...
# Loading dataset shards:   0%|          | 0/36 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#       9 from config import TRAIN_SIZE, VALIDATION_SIZE, TEST_SIZE
#      10 from models import GAN, Generator, Critic
#      11
#      12 # Load ImageNet 256x256 from HuggingFace
# ---> 13 ds = load_dataset(
#      14     "benjamin-paine/imagenet-1k-256x256"
#      15 )
#      16
#
# File e:\computational-imaging\.venv\Lib\site-packages\datasets\load.py:1720, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1716 # Build dataset for splits
#    1717 keep_in_memory = (
# ...
